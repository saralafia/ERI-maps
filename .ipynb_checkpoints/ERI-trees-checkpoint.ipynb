# %%
# Goal: hierarchical clustering of 70 topic model, topic clustering as TREE
# To do: move to plotly dash
# Resource: https://stackabuse.com/hierarchical-clustering-with-python-and-scikit-learn/

# Helper libraries
import pandas as pd
import numpy as np
import random
import spacy

# Dimensionality reduction (topic model, embedding)
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF
from sklearn.manifold import TSNE
from sklearn.cluster import AgglomerativeClustering

# Plotting tools
import scipy.cluster.hierarchy as shc
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# %matplotlib inline

# %%
# DATA Load preprocessed documents (articles, projects) from csv; create text column 'combined' (title, abstract)
print("Loading documents")
df = pd.read_csv("data/ERI-combined-full-2009-2019.csv")
df['combined'] = df['title'].astype(str) + ' ' + df['abstract'].astype(str)
print(len(df))
df.head()
# Out:
# Loading documents
# 3770
#       id  start_year  end_year  \
# 0     0a        2019      2019
# 1  1000a        2014      2014
# 2  1001a        2014      2014
# 3  1002a        2014      2014
# 4  1003a        2014      2014
#
#                                                title  \
# 0  Proteomic, gene and metabolite characterizatio...
# 1  Evaluation of Aquarius Level 2 Soil Moisture P...
# 2  Fusion of Space-Based CO2 Products and its Com...
# 3  Water Vapor Retrieval Over Cloud Cover Area on...
# 4  Toward Accurate XCO2 Level 2 Measurements by C...
#
#                                             abstract     type  \
# 0  Cadmium sulfide quantum dots regulate nanomate...  article
# 1  Validation is important for any satellite-base...  article
# 2  Currently, ascertaining and quantifying the gl...  article
# 3  This study mainly discusses atmospheric water ...  article
# 4  Carbon dioxide (CO2) is one of the most import...  article
#
#                                              authors  \
# 0  Majumdar, Sanghamitra; Pagano, Luca; Wohlschle...
# 1  Li, Dongyang; Zhao, Tianjie; Shi, Jiancheng; B...
# 2     Jing, Yingying; Shi, Jiancheng; Wang, Tianxing
# 3                          Ji, Dabin; Shi, Jiancheng
# 4     Jing, Yingying; Wang, Tianxing; Shi, Jiancheng
#
#                     identifier  \
# 0           10.1039/c9en00599d
# 1  10.1109/igarss.2014.6946966
# 2  10.1109/igarss.2014.6946946
# 3  10.1109/jstars.2014.2298979
# 4   10.1109/eorsa.2014.6927857
#
#                                             combined
# 0  Proteomic, gene and metabolite characterizatio...
# 1  Evaluation of Aquarius Level 2 Soil Moisture P...
# 2  Fusion of Space-Based CO2 Products and its Com...
# 3  Water Vapor Retrieval Over Cloud Cover Area on...
# 4  Toward Accurate XCO2 Level 2 Measurements by C...

# %%
# NLP Remove stopwords, vectorize text with unigrams and bigrams, construct matrix of TFIDF features
np.random.seed(13) #set random seed for reproducbility
n_features = 1000 #optional - number of features ordered by term frequency to include in model
#n_topics = 9 #number of topics - coarse thematic granularity
n_topics = 70 #number of topics- fine thematic granularity
n_top_words = 10 #number of keywords returned per topic

custom_stop_words = []
with open( "mallet-2.0.8/stoplists/en-custom.txt", "r" ) as fin:  #load custom stop word list
    for line in fin.readlines():
        custom_stop_words.append( line.strip().lower() )
        
tfidf_vectorizer = TfidfVectorizer(min_df=2, ngram_range=(1,2), stop_words=custom_stop_words)
tfidf = tfidf_vectorizer.fit_transform(df['combined'])
print( "Created %d X %d TF-IDF-normalized document-term matrix" % (tfidf.shape[0], tfidf.shape[1]) ) #terms by features
# Out:
# Created 3770 X 80152 TF-IDF-normalized document-term matrix

# %%
# TOPIC MODEL build embedding for topics, return topics and keywords
nmf = NMF(n_components=n_topics, init="nndsvd").fit(tfidf) # create the model

def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
        print()
        
print("Topics found via NMF:")
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(nmf, tfidf_feature_names, n_top_words)
# Out:
# Topics found via NMF:
#
# Topic #0:
# science ecological social information systems processes management scientific natural environmental
#
#
# Topic #1:
# crust subduction continental continental crust mantle crustal rocks arc uhp pressure
#
#
# Topic #2:
# snow swe snow cover cover snow water water equivalent equivalent snow depth modis albedo
#
#
# Topic #3:
# soil moisture moisture soil band smap surface surface soil roughness algorithm m3
#
#
# Topic #4:
# climate climate change change future impacts adaptation chapter global responses change impacts
#
#
# Topic #5:
# species habitat plant species abundance plant distribution tree conservation species distribution occupancy
#
#
# Topic #6:
# rupture earthquake ground motion ground motion earthquakes stress slip velocity al
#
#
# Topic #7:
# mantle 3he lavas 4he 3he 4he samoan plume geochemical hotspot high 3he
#
#
# Topic #8:
# ice ice sheet sheet antarctic greenland ka glacial antarctic ice retreat holocene
#
#
# Topic #9:
# severity burn burn severity post fire post fire mesma vegetation landsat mediterranean
#
#
# Topic #10:
# cryogenian formation neoproterozoic glacial cambrian ma group fossils ca age
#
#
# Topic #11:
# fire wildfire fires burned fire regimes regimes fire management fire regime post fire california
#
#
# Topic #12:
# ocean phytoplankton color ocean color optical satellite algorithms products chlorophyll particle
#
#
# Topic #13:
# carbon export ocean production carbon export organic carbon poc organic particle pump
#
#
# Topic #14:
# precipitation annual streamflow winter himalaya rain summer western daily wwd
#
#
# Topic #15:
# restoration open space campus slough open devereux space acres wetland north campus
#
#
# Topic #16:
# water energy availability water availability riparian water scarcity scarcity water quality quality water resources
#
#
# Topic #17:
# soil microbial soils plant organic microbial biomass dry rewetting soil microbial biomass
#
#
# Topic #18:
# methane ch4 emissions bubble gas plume aviris sources seep plumes
#
#
# Topic #19:
# nanoparticles nps zno tio2 enps ag toxicity aggregation bacterial metal
#
#
# Topic #20:
# fecal human sources assays source tracking contamination fib source tracking pollution
#
#
# Topic #21:
# kelp giant kelp giant macrocystis pyrifera kelp forests biomass macrocystis pyrifera kelp macrocystis synchrony
#
#
# Topic #22:
# fault slip faults zone fault zone slip rates earthquake strike km fault slip
#
#
# Topic #23:
# erosion rates erosion rates 10be landscape mm relief himalaya rate uplift
#
#
# Topic #24:
# de la en para des el de la las los del
#
#
# Topic #25:
# diversity richness biomass biodiversity plant species richness productivity plant diversity stability communities
#
#
# Topic #26:
# sediment hg transport suspended suspended sediment sediment supply sediment flux supply sediment transport flux
#
#
# Topic #27:
# borehole scec program scec borehole stations pbic california borehole stations borehole instrumentation instrumentation
#
#
# Topic #28:
# spectral endmember imaging mapping infrared mesma hyperspectral accuracy spectra resolution
#
#
# Topic #29:
# sierra nevada sierra nevada walker volcanic arc central sierra california range front front
#
#
# Topic #30:
# lst surface temperature land surface emissivity modis surface temperature land algorithm tir
#
#
# Topic #31:
# wave waves rayleigh velocity seismic surface wind rayleigh wave love breaking
#
#
# Topic #32:
# sea sea level level bay level rise rise gulf gulf mexico mexico holocene
#
#
# Topic #33:
# fisheries fishery marine management fishing mpas reserves fish protected mpa
#
#
# Topic #34:
# zircon monazite ma dates pb metamorphism ages garnet metamorphic crystallization
#
#
# Topic #35:
# population dispersal populations demographic dynamics heterogeneity larval connectivity genetic population dynamics
#
#
# Topic #36:
# enms enm nanomaterials engineered nanomaterials engineered exposure release environmental nanomaterials enms environment
#
#
# Topic #37:
# land land cover cover land change areas conservation agricultural deforestation crop habitat
#
#
# Topic #38:
# vegetation microwave mvis vegetation indices indices microwave vegetation optical optical depth windsat ndvi
#
#
# Topic #39:
# forest forests deforestation tree drought trees canopy mortality biomass thinning
#
#
# Topic #40:
# shear stz gouge grain granular fault gouge strain weakening theory energy
#
#
# Topic #41:
# litter decomposition uv photodegradation radiation uv radiation exposure litter decomposition lignin arid
#
#
# Topic #42:
# conservation horizon issues horizon scan scan global conservation topics global biological diversity annual horizon
#
#
# Topic #43:
# groundwater recharge streamflow tracer 35s groundwater recharge aquifer wells sf6 travel
#
#
# Topic #44:
# adaptation risk policy public farmers social risks coffee maize economic
#
#
# Topic #45:
# native exotic grasses grass perennial invasion invasive native species invasions annual
#
#
# Topic #46:
# rainfall extreme extreme rainfall events seasonal rainfall rainfall events andes season intensity seasonal
#
#
# Topic #47:
# cu nano mg plants nanopesticide copper cucumber nano cu metabolomics ms
#
#
# Topic #48:
# ma himalayan crustal himalaya deformation rocks shear exhumation pamir tibetan
#
#
# Topic #49:
# floodplain amazon river amazon floodplain inundation flood floodplains wetlands basin amazon basin
#
#
# Topic #50:
# model models deb modeling parameters watershed simulation energy dynamic dynamic energy
#
#
# Topic #51:
# services ecosystem ecosystem services management ecosystems provision biodiversity service ecosystem service provision ecosystem
#
#
# Topic #52:
# mjo extreme precipitation extreme oscillation precipitation events predictability forecasts skill forecast
#
#
# Topic #53:
# lakes lake mixing turbulence wind stratification gas emerald high elevation emerald lake
#
#
# Topic #54:
# co2 global gosat xco2 emissions sciamachy measurements co2 products atmospheric co2 carbon
#
#
# Topic #55:
# 10be meteoric 10be meteoric samples 26al 9be cosmogenic regolith 10be concentrations concentrations
#
#
# Topic #56:
# coral reef corals coral reef reefs coral reefs prey predator symbiont fish
#
#
# Topic #57:
# uc cein nanotechnology uc cein nanomaterials university columbia implications nanotechnology risk environmental
#
#
# Topic #58:
# infrasound volcanic acoustic volcano eruption explosive seismic eruptions source volcanoes
#
#
# Topic #59:
# monsoon south sams south america american monsoon america american atlantic variability monsoon system
#
#
# Topic #60:
# mesoporous materials energy metal cell lithium synthesis ordered performance material
#
#
# Topic #61:
# warming snowmelt arctic temperature timing sea ice temperatures summer climate earlier
#
#
# Topic #62:
# oil spill deepwater horizon deepwater oil spill horizon bubble gulf gulf mexico mexico
#
#
# Topic #63:
# urban growth urban growth maize tree household urban areas cities food urbanization
#
#
# Topic #64:
# inclusions melt melt inclusions magma isotopic 87sr 87sr 86sr 86sr lavas mangaia
#
#
# Topic #65:
# cdom ocean dom dissolved organic dissolved organic matter organic matter doc absorption
#
#
# Topic #66:
# life cycle lca life cycle environmental cycle assessment assessment emissions impacts technologies
#
#
# Topic #67:
# mag removal pcmas mag pcmas cd nzvi fe iron magnetic nitrate
#
#
# Topic #68:
# basin plateau deformation basins uplift incision shan margin fluvial foreland
#
#
# Topic #69:
# channel flow river habitat salmon gravel bed reach chinook chinook salmon

# %%
# TOPIC MODEL transform tfidf-matrix into nmf-embedding
nmf_embedding = nmf.transform(tfidf)
top_idx = np.argsort(nmf_embedding,axis=0)[-3:]

count = 0
for idxs in top_idx.T: 
    print("\nTopic {}:".format(count))
    for idx in idxs:
        print(df.iloc[idx]['title'])  
        print(df.iloc[idx]['authors'])
    count += 1

print( "Created %d X %d document-topic matrix" % (nmf_embedding.shape[0], nmf_embedding.shape[1]) )
# Out:
# Created 3770 X 70 document-topic matrix
# [9.33788045e-06 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  5.56994809e-04 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 6.28377814e-04
#  6.40709345e-05 0.00000000e+00 9.28164998e-05 0.00000000e+00
#  0.00000000e+00 4.14225818e-05 3.40161906e-04 3.76845510e-03
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  2.04332520e-04 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 3.76916345e-06 2.09412964e-03
#  7.83289498e-04 3.85723597e-03 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 3.48453429e-04 0.00000000e+00
#  1.00947599e-03 0.00000000e+00 2.81964369e-04 4.14114064e-02
#  0.00000000e+00 0.00000000e+00 1.45362322e-03 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.98329545e-05 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.31326065e-02 4.93431684e-03
#  6.32198803e-04 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  3.22375002e-02 0.00000000e+00 0.00000000e+00 1.00489751e-01
#  0.00000000e+00 0.00000000e+00]

# %%
tsne = TSNE(perplexity=7, early_exaggeration=5, random_state=3211)
tsne_embedding = tsne.fit_transform(nmf_embedding.T)
tsne_embedding = pd.DataFrame(tsne_embedding,columns=['x','y'])
print( "Created %d X %d matrix" % (tsne_embedding.shape[0], tsne_embedding.shape[1]) )
# Out:
# Created 70 X 2 matrix

# %%
# Determine number of clusters for splitting data; minimize distance between topics based on term weights
plt.figure(figsize=(10, 7))
plt.title("Topic Dendogram")
dend = dendrogram(shc.linkage(tsne_embedding, method='ward',))
cluster = AgglomerativeClustering(n_clusters=4, affinity='euclidean', linkage='ward')
cluster.fit_predict(tsne_embedding)
#plt.savefig("figures/NMF-t-SNE-70-topic-dendrogram.png", dpi=300)
# Out:
# array([2, 2, 2, 0, 2, 0, 2, 0, 2, 1, 2, 1, 1, 2, 0, 2, 1, 2, 0, 0, 1, 2,
#        2, 0, 2, 0, 2, 2, 0, 1, 1, 2, 0, 2, 2, 2, 1, 1, 0, 2, 2, 0, 2, 2,
#        0, 2, 2, 2, 2, 2, 2, 1, 0, 1, 0, 1, 2, 2, 1, 2, 0, 0, 1, 0, 0, 3,
#        0, 1, 0, 0])
