# %%
# Goal: hierarchical clustering of 70 topic model, topic clustering as TREE
# To do: move to plotly dash
# Resource: https://stackabuse.com/hierarchical-clustering-with-python-and-scikit-learn/

# Helper libraries
import pandas as pd
import numpy as np
import random
import spacy

# Dimensionality reduction (topic model, embedding)
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF
from sklearn.manifold import TSNE
from sklearn.cluster import AgglomerativeClustering

# Plotting tools
import scipy.cluster.hierarchy as shc
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# %matplotlib inline

# %%
# DATA Load preprocessed documents (articles, projects) from csv; create text column 'combined' (title, abstract)
print("Loading documents")
df = pd.read_csv("data/ERI-combined-full-2009-2019.csv")
df['combined'] = df['title'].astype(str) + ' ' + df['abstract'].astype(str)
print(len(df))
df.head()
# Out:
# Loading documents
# 3770
#       id  start_year  end_year  \
# 0     0a        2019      2019
# 1  1000a        2014      2014
# 2  1001a        2014      2014
# 3  1002a        2014      2014
# 4  1003a        2014      2014
#
#                                                title  \
# 0  Proteomic, gene and metabolite characterizatio...
# 1  Evaluation of Aquarius Level 2 Soil Moisture P...
# 2  Fusion of Space-Based CO2 Products and its Com...
# 3  Water Vapor Retrieval Over Cloud Cover Area on...
# 4  Toward Accurate XCO2 Level 2 Measurements by C...
#
#                                             abstract     type  \
# 0  Cadmium sulfide quantum dots regulate nanomate...  article
# 1  Validation is important for any satellite-base...  article
# 2  Currently, ascertaining and quantifying the gl...  article
# 3  This study mainly discusses atmospheric water ...  article
# 4  Carbon dioxide (CO2) is one of the most import...  article
#
#                                              authors  \
# 0  Majumdar, Sanghamitra; Pagano, Luca; Wohlschle...
# 1  Li, Dongyang; Zhao, Tianjie; Shi, Jiancheng; B...
# 2     Jing, Yingying; Shi, Jiancheng; Wang, Tianxing
# 3                          Ji, Dabin; Shi, Jiancheng
# 4     Jing, Yingying; Wang, Tianxing; Shi, Jiancheng
#
#                     identifier  \
# 0           10.1039/c9en00599d
# 1  10.1109/igarss.2014.6946966
# 2  10.1109/igarss.2014.6946946
# 3  10.1109/jstars.2014.2298979
# 4   10.1109/eorsa.2014.6927857
#
#                                             combined
# 0  Proteomic, gene and metabolite characterizatio...
# 1  Evaluation of Aquarius Level 2 Soil Moisture P...
# 2  Fusion of Space-Based CO2 Products and its Com...
# 3  Water Vapor Retrieval Over Cloud Cover Area on...
# 4  Toward Accurate XCO2 Level 2 Measurements by C...

# %%
# NLP Remove stopwords, vectorize text with unigrams and bigrams, construct matrix of TFIDF features
np.random.seed(13) #set random seed for reproducbility
n_features = 1000 #optional - number of features ordered by term frequency to include in model
#n_topics = 9 #number of topics - coarse thematic granularity
n_topics = 36 #number of topics - coarse thematic granularity
#n_topics = 70 #number of topics- fine thematic granularity
n_top_words = 10 #number of keywords returned per topic

custom_stop_words = []
with open( "mallet-2.0.8/stoplists/en-custom.txt", "r" ) as fin:  #load custom stop word list
    for line in fin.readlines():
        custom_stop_words.append( line.strip().lower() )
        
tfidf_vectorizer = TfidfVectorizer(min_df=2, ngram_range=(1,2), stop_words=custom_stop_words)
tfidf = tfidf_vectorizer.fit_transform(df['combined'])
print( "Created %d X %d TF-IDF-normalized document-term matrix" % (tfidf.shape[0], tfidf.shape[1]) ) #terms by features
# Out:
# Created 3770 X 80046 TF-IDF-normalized document-term matrix

# %%
# TOPIC MODEL build embedding for topics, return topics and keywords
nmf = NMF(n_components=n_topics, init="nndsvd").fit(tfidf) # create the model

def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
        print()
        
print("Topics found via NMF:")
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(nmf, tfidf_feature_names, n_top_words)
# Out:
# Topics found via NMF:
#
# Topic #0:
# wave waves seismic velocity rayleigh pressure surface structure wind noise
#
#
# Topic #1:
# deformation crustal ma pamir shear himalayan rocks exhumation tibetan himalaya
#
#
# Topic #2:
# snow swe snow cover cover snow water water equivalent snowmelt equivalent snowpack snow depth
#
#
# Topic #3:
# soil moisture moisture soil band smap surface roughness surface soil algorithm m3
#
#
# Topic #4:
# climate climate change change adaptation future impacts models responses global species
#
#
# Topic #5:
# species diversity richness plant native species richness biodiversity communities biomass abundance
#
#
# Topic #6:
# fault slip rupture earthquake faults motion earthquakes ground ground motion seismic
#
#
# Topic #7:
# mantle lavas isotopic crust 3he samoan 4he 3he 4he geochemical melt
#
#
# Topic #8:
# soil microbial soils plant biomass organic microbial biomass dry nitrogen soil microbial
#
#
# Topic #9:
# amazon floodplain forest river basin deforestation amazon floodplain inundation cover forests
#
#
# Topic #10:
# ice ice sheet sheet antarctic greenland glacial ka retreat antarctic ice holocene
#
#
# Topic #11:
# fire wildfire fires burned severity post fire burn post burn severity fire regimes
#
#
# Topic #12:
# ocean color phytoplankton ocean color cdom optical satellite algorithms particle chlorophyll
#
#
# Topic #13:
# carbon co2 emissions global carbon dioxide export dioxide fluxes flux measurements
#
#
# Topic #14:
# rainfall precipitation extreme mjo monsoon events variability south oscillation america
#
#
# Topic #15:
# erosion 10be rates erosion rates meteoric 10be meteoric landscape uplift rate cosmogenic
#
#
# Topic #16:
# water groundwater recharge streamflow drought hydrologic riparian energy river storage
#
#
# Topic #17:
# spectral endmember mapping imaging mesma infrared accuracy hyperspectral cover urban
#
#
# Topic #18:
# methane ch4 oil bubble emissions gas plume seep aviris plumes
#
#
# Topic #19:
# nanoparticles cu nps zno nano toxicity mg metal tio2 enps
#
#
# Topic #20:
# fecal human sources source assays tracking contamination fib pollution samples
#
#
# Topic #21:
# kelp giant kelp giant biomass macrocystis pyrifera kelp forests forests macrocystis pyrifera kelp macrocystis
#
#
# Topic #22:
# fisheries marine fishery management fishing mpas reserves fish protected mpa
#
#
# Topic #23:
# restoration open space campus slough open devereux space acres habitat wetland
#
#
# Topic #24:
# conservation services ecosystem management policy ecosystem services land biodiversity social adaptation
#
#
# Topic #25:
# lakes lake mixing turbulence wind stratification emerald high elevation arctic gas
#
#
# Topic #26:
# borehole scec program scec borehole pbic stations california borehole stations network earthquake
#
#
# Topic #27:
# land lst surface temperature land surface emissivity modis surface temperature microwave algorithm
#
#
# Topic #28:
# sediment channel river transport flow hg sediment supply bed supply suspended
#
#
# Topic #29:
# vegetation microwave mvis vegetation indices indices optical microwave vegetation optical depth ndvi windsat
#
#
# Topic #30:
# litter decomposition uv photodegradation radiation uv radiation exposure litter decomposition lignin arid
#
#
# Topic #31:
# sierra nevada sierra nevada volcanic arc basin walker ma central sierra faults
#
#
# Topic #32:
# life cycle environmental life lca cycle assessment enms cycle assessment nanomaterials impacts
#
#
# Topic #33:
# population model models dynamics deb growth populations theory individual dispersal
#
#
# Topic #34:
# zircon ma monazite dates pb metamorphism rocks ages garnet uhp
#
#
# Topic #35:
# sea sea level level bay level rise rise gulf gulf mexico mexico holocene

# %%
# TOPIC MODEL transform tfidf-matrix into nmf-embedding
nmf_embedding = nmf.transform(tfidf)
top_idx = np.argsort(nmf_embedding,axis=0)[-3:]

count = 0
for idxs in top_idx.T: 
    print("\nTopic {}:".format(count))
    for idx in idxs:
        print(df.iloc[idx]['title'])  
        print(df.iloc[idx]['authors'])
    count += 1

print( "Created %d X %d document-topic matrix" % (nmf_embedding.shape[0], nmf_embedding.shape[1]) )
# Out:
# Topic 0:
# An approach to improve Rayleigh-wave ellipticity estimates from seismic noise: application to the Los Angeles Basin
# Tanimoto, Toshiro; Yano, Tomoko; Hakamata, Tomohiro
# SCEC3 Participation: Using Seismic noise for the purpose of improving shallow S-wave velocity models
# Toshiro Tanimoto
# SCEC3: Using Seismic noise for the purpose of improving shallow S-wave velocity models
# Toshiro Tanimoto; Ralph Archuleta
#
# Topic 1:
# Tectonic evolution of the middle crust in southern Tibet from structural and kinematic studies in the Lhagoi Kangri gneiss dome
# Diedesch, Timothy F.; Jessup, Micah J.; Cottle, John M.; Zeng, Lingsen
# Building the Pamir Tibetan PlateauCrustal stacking, extensional collapse, and lateral extrusion in the Central Pamir: 1. Geometry and kinematics
# Rutte, Daniel; Ratschbacher, Lothar; Schneider, Susanne; St  bner, Konstanze; Stearns, Michael A.; Gulzar, Muhammad A.; Hacker, Bradley R.
# Direct shear fabric dating constrains early Oligocene onset of the South Tibetan detachment in the western Nepal Himalaya
# La Roche, Renaud Soucy; Godin, Laurent; Cottle, John M.; Kellett, Dawn A.
#
# Topic 2:
# Remote sensing of snow in China
# Shi, Jiancheng; Jiang, Lingmei; Zhao, Tianjie; Xiong, Chuan
# Error Analysis of MODIS Fractional Snow-Covered Area and Snow Albedo in Mountain Regions
# Jeff Dozier; James Frew
# Error Analysis of MODIS Fractional Snow-Covered Area and Snow Albedo in Mountain Regions
# Jeff Dozier; James Frew
#
# Topic 3:
# Analysis of spatial distribution and multi-year trend of the remotely sensed soil moisture on the Tibetan Plateau
# Liu, Qiang; Du, JinYang; Shi, JianCheng; Jiang, LingMei
# SOIL MOISTURE RETRIEVAL BY REMOTE SENSING AND MULTI-YEAR TREND ANALYSIS OF THE SOIL MOISTURE IN TIBETAN PLATEAU
# Global separation of plant transpiration from groundwater and streamflow
# Evaristo, Jaivime; Jasechko, Scott; McDonnell, Jeffrey J.
# Headwaters to groundwater: Resources in a changing climate
# Jeff Dozier
#
# Topic 17:
# Evaluation of potential of multiple endmember spectral mixture analysis (MESMA) for surface coal mining affected area mapping in different world forest ecosystems
# Fern  ndez-Manso, Alfonso; Quintano, Carmen; Roberts, Dar
# A multi-temporal spectral library approach for mapping vegetation species across spatial and temporal phenological gradients
# Dudley, Kenneth L.; Dennison, Philip E.; Roth, Keely L.; Roberts, Dar A.; Coates, Austin R.
# Enhancing the performance of Multiple Endmember Spectral Mixture Analysis (MESMA) for urban land cover mapping using airborne lidar data and band selection
# Degerickx, J.; Roberts, D.A.; Somers, B.
#
# Topic 18:
# Mapping methane emissions from a marine geological seep source using imaging spectrometry
# Roberts, Dar A.; Bradley, Eliza S.; Cheung, Ross; Leifer, Ira; Dennison, Philip E.; Margolis, Jack S.
# Considerable methane fluxes to the atmosphere from hydrocarbon seeps in the Gulf of Mexico
# Solomon, Evan A.; Kastner, Miriam; MacDonald, Ian R.; Leifer, Ira
# Detection of marine methane emissions with AVIRIS band ratios
# Bradley, Eliza S.; Leifer, Ira; Roberts, Dar A.; Dennison, Philip E.; Washburn, Libe
#
# Topic 19:
# Impacts of metal oxide nanoparticles on marine phytoplankton.
# Miller, Robert J; Lenihan, Hunter S; Muller, Erik B; Tseng, Nancy; Hanna, Shannon K; Keller, Arturo A
# Cu Nanoparticles Have Different Impacts in Escherichia coli and Lactobacillus brevis than Their Microsized and Ionic Analogues.
# Kaweeteerawat, Chitrada; Chang, Chong Hyun; Roy, Kevin R; Liu, Rong; Li, Ruibin; Toso, Daniel; Fischer, Heidi; Ivask, Angela; Ji, Zhaoxia; Zink, Jeffrey I; Zhou, Z Hong; Chanfreau, Guillaume Francois; Telesca, Donatello; Cohen, Yoram; Holden, Patricia Ann; Nel, Andre E; Godwin, Hilary A
# Comparative environmental fate and toxicity of copper nanomaterials
# Keller, Arturo A.; Adeleye, Adeyemi S.; Conway, Jon R.; Garner, Kendra L.; Zhao, Lijuan; Cherr, Gary N.; Hong, Jie; Gardea-Torresdey, Jorge L.; Godwin, Hilary A.; Hanna, Shannon; Ji, Zhaoxia; Kaweeteerawat, Chitrada; Lin, Sijie; Lenihan, Hunter S.; Miller, Robert J.; Nel, Andr   E.; Peralta-Videa, Jose R.; Walker, Sharon L.; Taylor, Alicia A.; Torres-Duarte, Cristina; Zink, Jeffrey I.; Zuverza-Mena, Nubia
#
# Topic 20:
# Performance of human fecal anaerobe-associated PCR-based assays in a multi-laboratory method evaluation study
#
# Topic 25:
# Morphometry and Physical Processes of East African Soda Lakes
# Melack, John M.; MacIntyre, Sally
# Depth integrated estimates of ecosystem metabolism in a high elevation lake (Emerald Lake, Sierra Nevada, California)
# Sadro, Steven; Melack, John M.; MacIntyre, Sally
# Responses of High Elevation Aquatic Ecosystems to Interannual Climate Variability and Trends in Nutrient Inputs(LTREB Program - REU Supplement)
# John Melack
#
# Topic 26:
# SCEC4 Participation Project A: SCEC Borehole Instrumentation Center
# Jamison Steidl; Ralph Archuleta
# SCEC4 Participation Project A: SCEC Borehole Instrumentation Center
# Jamison Steidl; Ralph Archuleta
# SCEC3 Participation: SCEC Borehole Instrumentation Program
# Jamison Steidl
#
# Topic 27:
# Science Data Analysis Including TIR BRDF Retrieval for Improvements of the MODIS Land-Surface Temperature/Emissivity Products in Long-term Accuracy and Consistancy
# Zhengming Wan
# MODIS Land Surface Temperature and Emissivity
# Wan, Zhengming; Li, Zhao-Liang
# AN EMISSIVITY-BASED LAND SURFACE TEMPERATURE RETRIEVAL ALGORITHM
# Qiu, Yubao; Guo, Huadong; Shi, Jiancheng; Lemmetyinen, Juha; Shi, Lijuan
#
# Topic 28:
# Impact of coarse sediment supply from hillslopes to the channel in runoff dominated, dryland fluvial systems
# Michaelides, Katerina; Singer, Michael Bliss
# Transient response in longitudinal grain size to reduced gravel supply in a large river
# Singer, Michael Bliss
# The impact of the streamflow hydrograph on sediment supply from terrace erosion
# Higson, John Lee; Singer, Michael Bliss
#
# Topic 29:
# MICROWAVE VEGETATION INDEX FROM SMOS
# Shi, Jiancheng; Li, Yunqing
# A STUDY ON ESTIMATION OF ABOVEGROUND WET BIOMASS BASED ON THE MICROWAVE VEGETATION INDICES
# Chai, Linna; Shi, J.; Du, J.; Tao, J.; Jackson, T; O'neill, P. E.; Zhang, L.; Qu, Y.; Wang, J.
# Microwave Vegetation Indices and the Application for Vegetation Optical Depth Retrieval using WindSat Data
# Li, Yunqing; Shi, Jiancheng
#
# Topic 30:
# Foliar litter chemistry mediates susceptibility to UV degradation in two dominant species from a semi-arid ecosystem
# Esch, Ellen H.; King, Jennifer Y.; Cleland, Elsa E.
# Effects of UV photodegradation on subsequent microbial decomposition of Bromus diandrus litter
# Lin, Yang; Scarlett, Rachel D.; King, Jennifer Y.
# Effects of UV Exposure and Litter Position on Decomposition in a California Grassland
# Lin, Yang; King, Jennifer Y.
#
# Topic 31:
# Geological Constraints on Landscape Evolution of the Sierra Nevada California: Paleochannels Magmatism and Structure
# Cathy Busby
# Miocene evolution of the western edge of the Nevadaplano in the central and northern Sierra Nevada: palaeocanyons, magmatism, and structure
# Busby, Cathy J.; Putirka, Keith
# Landscape Evolution of the Sierra Nevada California: Paleochannels Magnatism and Structure
# Cathy Busby
#
# Topic 32:
# Modeling human health characterization factors for indoor nanomaterial emissions in life cycle assessment: a case-study of titanium dioxide
# Tsang, Michael P.; Li, Dingsheng; Garner, Kendra L.; Keller, Arturo A.; Suh, Sangwon; Sonnemann, Guido W.
# 6 Life cycle assessment of engineered nanomaterials
# Gavankar, S.; Suh, S.; Keller, A.A.
# Life cycle assessment at nanoscale: review and recommendations
# Gavankar, Sheetal; Suh, Sangwon; Keller, Arturo F.
#
# Topic 33:
# Limitations of extrapolating toxic effects on reproduction to the population level
# Martin, Benjamin; Jager, Tjalling; Nisbet, Roger M.; Preuss, Thomas G.; Grimm, Volker
# Dynamic energy budget theory and population ecology: lessons from Daphnia
# Nisbet, Roger M.; McCauley, Edward; Johnson, Leah R.
# Predicting population dynamics from the properties of individuals: a cross-level test of dynamic energy budget theory.
# Martin, Benjamin T; Jager, Tjalling; Nisbet, Roger M; Preuss, Thomas G; Grimm, Volker
#
# Topic 34:
# Monazite trace-element and isotopic signatures of (ultra)high-pressure metamorphism: Examples from the Western Gneiss Region, Norway
# Holder, Robert M.; Hacker, Bradley R.; Kylander-Clark, Andrew R.C.; Cottle, John M.
# Insights into (U)HP metamorphism of the Western Gneiss Region, Norway: A high-spatial resolution and high-precision zircon study
# DesOrmeau, Joel W.; Gordon, Stacia M.; Kylander-Clark, Andrew R.C.; Hacker, Bradley R.; Bowring, Samuel A.; Schoene, Blair; Samperton, Kyle M.
# Coupled garnet Lu Hf and monazite U Pb geochronology constrain early convergent margin dynamics in the Ross orogen, Antarctica
# Hagen   Peter, G.; Cottle, J. M.; Smit, M.; Cooper, A. F.
#
# Topic 35:
# Breaching of Mustang Island in response to the 8.2 ka sea-level event and impact on Corpus Christi Bay, Gulf of Mexico: Implications for future coastal change
# Ferguson, Shannon; Warny, Sophie; Anderson, John B; Simms, Alexander R; White, Crawford
# Variable response of coastal environments of the northwestern Gulf of Mexico to sea-level rise and climate change: Implications for future change
# Anderson, John B.; Wallace, Davin J.; Simms, Alexander R.; Rodriguez, Antonio B.; Milliken, Kristy T.
# New Approaches to Unraveling the Climatic and Sea-Level History of the Northwestern Gulf of Mexico
# Alex Simms
# Created 3770 X 36 document-topic matrix

# %%
# Reduce dimensionality
tsne = TSNE(perplexity=7, early_exaggeration=5, random_state=3211)
tsne_embedding = tsne.fit_transform(nmf_embedding.T)
tsne_embedding = pd.DataFrame(tsne_embedding,columns=['x','y'])
print( "Created %d X %d matrix" % (tsne_embedding.shape[0], tsne_embedding.shape[1]) )
# Out:
# Created 36 X 2 matrix

# %%
# Determine number of clusters for splitting data; minimize distance between topics based on term weights
plt.figure(figsize=(10, 7))
plt.title("Topic Dendrogram")
plt.xlabel("Topic")
plt.ylabel("Distance")
dend = dendrogram(shc.linkage(tsne_embedding, method='ward'),color_threshold=100)
#cluster = AgglomerativeClustering(n_clusters=4, affinity='euclidean', linkage='ward')
#cluster.fit_predict(tsne_embedding)
#plt.scatter(tsne_embedding[:,0], tsne_embedding[:,1], c=cluster.labels_, cmap='rainbow')
plt.savefig("figures/NMF-t-SNE-36-topic-dendrogram-ward.png", dpi=300)
